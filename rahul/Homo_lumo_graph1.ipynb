# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj18/hello_world/blob/master/rahul/Homo_lumo_graph1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9141716d-8cc5-49ae-9e9e-0b0b6265e3ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9141716d-8cc5-49ae-9e9e-0b0b6265e3ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Homo_Lumo_gap.xlsx to Homo_Lumo_gap.xlsx
# User uploaded file "Homo_Lumo_gap.xlsx" with length 12682 bytes

# %%
data=pd.read_excel('Homo_Lumo_gap.xlsx')

# %%
data
# Out:
#      Thia [n]helicenes, n=1-10  ... Unnamed: 18
# 0                          NaN  ...         NaN
# 1                          NaN  ...         NaN
# 2                          NaN  ...         NaN
# 3                          NaN  ...         NaN
# 4                          NaN  ...         NaN
# 5                          NaN  ...         NaN
# 6                          NaN  ...         NaN
# 7                          NaN  ...         NaN
# 8                          NaN  ...         NaN
# 9                          NaN  ...         NaN
# 10                         NaN  ...         NaN
# 11                         NaN  ...         NaN
# 12                         NaN  ...         NaN
# 13  seleno[n]helicenes, n=1-10  ...         NaN
# 14                         NaN  ...         NaN
# 15                         NaN  ...         NaN
# 16                         NaN  ...         NaN
# 17                         NaN  ...         NaN
# 18                         NaN  ...         NaN
# ...

# %%
columns=list(data.iloc[0,1:16])

# %%
data_thia=data.iloc[1:11,1:16]
data_thia.columns=columns
data_thia=data_thia.reset_index(drop=True)
data_thia
# Out:
#   number of rings  BLYP B3LYP B3LYP-D  ... #LC-BLYP     HF   MP2   CCSD
# 0               1  4.36  5.99    5.98  ...    10.56  10.24  9.99  10.09
# 1               2  3.96  5.49    5.48  ...     9.92   9.57  9.37   9.46
# 2               3  3.65  5.13    5.12  ...     9.57    9.2  9.02   9.11
# 3               4  3.44  4.87    4.86  ...     9.35   9.04  8.84   8.96
# 4               5   3.3  4.71    4.71  ...     9.25   8.97  8.77    NaN
# 5               6  3.22  4.62    4.62  ...     9.22   8.95  8.72    NaN
# 6               7  3.13  4.53    4.52  ...      9.2   8.96  8.76    NaN
# 7               8  3.05  4.49    4.85  ...     9.17    9.1  8.87    NaN
# 8               9     3  4.43    4.45  ...     9.12   9.16   8.9    NaN
# 9              10  2.98   4.4    4.41  ...     9.07   9.15  8.84    NaN
#
# [10 rows x 15 columns]

# %%
data_seleno=data.iloc[15:25,1:16]
data_seleno.columns=columns
data_seleno=data_seleno.reset_index(drop=True)
data_seleno
# Out:
#   number of rings  BLYP B3LYP B3LYP-D  ... #LC-BLYP     HF   MP2   CCSD
# 0               1  4.19  5.79    5.78  ...     10.4  10.09  9.98  10.09
# 1               2   3.6  5.03    5.03  ...     9.66   9.37  9.29   9.35
# 2               3  3.34  4.74    4.73  ...     9.41   9.08   8.9      9
# 3               4  3.13   4.5    4.49  ...     9.09   8.89  8.71   8.83
# 4               5  2.99  4.34    4.33  ...     8.92   8.82  8.62    NaN
# 5               6  2.88  4.24    4.23  ...     8.84   8.85  8.63    NaN
# 6               7  2.76  4.16    4.13  ...     8.75   8.88  8.65    NaN
# 7               8  2.69  4.09    4.09  ...     8.69    8.9  8.64    NaN
# 8               9  2.68  4.06    4.05  ...     8.62   8.84  8.53    NaN
# 9              10  2.64     4    3.96  ...     8.54   8.74  8.38    NaN
#
# [10 rows x 15 columns]

# %%
data_telluro=data.iloc[29:39,1:16]
data_telluro.columns=columns
data_telluro=data_telluro.reset_index(drop=True)
data_telluro
# Out:
#   number of rings  BLYP B3LYP B3LYP-D  PBE0  ... #LC-ωPBE #LC-BLYP    HF   MP2  CCSD
# 0               1  3.73  5.14    5.12  7.22  ...     9.71     9.62  9.44  9.53  9.49
# 1               2  2.85  4.21    4.21  6.25  ...     8.89     8.84  8.87   8.8  8.84
# 2               3  2.61  3.97    3.97  5.99  ...     8.65     8.58  8.74   8.6  8.66
# 3               4  2.36   3.7     3.7   5.7  ...     8.36     8.28  8.54  8.39    --
# 4               5  2.22  3.56    3.57  5.55  ...     8.21     8.13   8.5  8.29   NaN
# 5               6  2.11  3.44    3.46  5.43  ...     8.09     8.01  8.44  8.25   NaN
# 6               7  2.03  3.36    3.37  5.33  ...     7.99     7.92  8.35  8.06   NaN
# 7               8  1.92  3.22     3.2  5.16  ...     7.83     7.76  8.19  7.92   NaN
# 8               9  1.87  3.17    3.12  5.08  ...     7.77     7.69  8.11  7.59   NaN
# 9              10  1.81  3.12    3.19  5.04  ...     7.71     7.63  8.04  7.65   NaN
#
# [10 rows x 15 columns]

# %%
cols=list(data.iloc[43,2:6])
cols
# Out:
# ['number of rings',
#  'Thia[n]helicene',
#  'seleno[n]helicene',
#  'Telluro[n]helicene']

# %%
data_helicene=data.iloc[44:54,2:6]
data_helicene.columns=cols
data_helicene=data_helicene.reset_index(drop=True)
data_helicene
# Out:
#   number of rings Thia[n]helicene seleno[n]helicene Telluro[n]helicene
# 0               1           10.64             10.39               9.66
# 1               2            9.89              9.62                8.9
# 2               3             9.6              9.41               8.66
# 3               4            9.36              9.18               8.37
# 4               5            9.24                 9               8.23
# 5               6            9.22              8.93               8.12
# 6               7             9.2              8.85               8.01
# 7               8            9.29              8.81               7.84
# 8               9            9.25              8.72               7.77
# 9              10            9.21              8.64               7.72

# %%
def plot_scatter(df,columns):
  plt.figure(figsize=(14,6))
  sns.set_context('paper', font_scale=1.4)
  plt.scatter(df['number of rings'],df[columns[1]],marker="s",label=columns[1])
  plt.scatter(df['number of rings'],df[columns[2]],marker="8",label=columns[2])
  plt.scatter(df['number of rings'],df[columns[3]],marker="p",label=columns[3])
  plt.scatter(df['number of rings'],df[columns[4]],marker="P",label=columns[4])
  plt.scatter(df['number of rings'],df[columns[5]],marker="*",label=columns[5])
  plt.scatter(df['number of rings'],df[columns[6]],marker="h",label=columns[6])
  plt.scatter(df['number of rings'],df[columns[7]],marker="+",label=columns[7])
  plt.scatter(df['number of rings'],df[columns[8]],marker="x",label=columns[8])
  plt.scatter(df['number of rings'],df[columns[9]],marker="d",label=columns[9])
  plt.scatter(df['number of rings'],df[columns[10]],marker="o",label=columns[10])
  plt.scatter(df['number of rings'],df[columns[11]],marker="v",label=columns[11])
  plt.scatter(df['number of rings'],df[columns[12]],marker="^",label=columns[12])
  plt.scatter(df['number of rings'],df[columns[13]],marker="<",label=columns[13])
  plt.scatter(df['number of rings'],df[columns[14]],marker=">",label=columns[14])
  plt.legend(bbox_to_anchor = ( 1.0, 0.8))
  plt.xticks(np.arange(1,11,step=1))
  plt.xlabel('n (number of rings)')
  plt.ylabel('HOMO-LUMO gap (eV)')

# %%
plot_scatter(data_thia,columns)

# %%
plot_scatter(data_seleno,columns)

# %%
plot_scatter(data_telluro,columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-224bcdfa1399> in <module>()
# ----> 1 plot_scatter(data_telluro,columns)
#
# <ipython-input-12-40db9993e5fe> in plot_scatter(df, columns)
#      15   plt.scatter(df['number of rings'],df[columns[12]],marker="^",label=columns[12])
#      16   plt.scatter(df['number of rings'],df[columns[13]],marker="<",label=columns[13])
# ---> 17   plt.scatter(df['number of rings'],df[columns[14]],marker=">",label=columns[14])
#      18   plt.legend(bbox_to_anchor = ( 1.0, 0.8))
#      19   plt.xticks(np.arange(1,11,step=1))
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
# ...

# %%
data_telluro
# Out:
#   number of rings  BLYP B3LYP B3LYP-D  PBE0  ... #LC-ωPBE #LC-BLYP    HF   MP2  CCSD
# 0               1  3.73  5.14    5.12  7.22  ...     9.71     9.62  9.44  9.53  9.49
# 1               2  2.85  4.21    4.21  6.25  ...     8.89     8.84  8.87   8.8  8.84
# 2               3  2.61  3.97    3.97  5.99  ...     8.65     8.58  8.74   8.6  8.66
# 3               4  2.36   3.7     3.7   5.7  ...     8.36     8.28  8.54  8.39    --
# 4               5  2.22  3.56    3.57  5.55  ...     8.21     8.13   8.5  8.29   NaN
# 5               6  2.11  3.44    3.46  5.43  ...     8.09     8.01  8.44  8.25   NaN
# 6               7  2.03  3.36    3.37  5.33  ...     7.99     7.92  8.35  8.06   NaN
# 7               8  1.92  3.22     3.2  5.16  ...     7.83     7.76  8.19  7.92   NaN
# 8               9  1.87  3.17    3.12  5.08  ...     7.77     7.69  8.11  7.59   NaN
# 9              10  1.81  3.12    3.19  5.04  ...     7.71     7.63  8.04  7.65   NaN
#
# [10 rows x 15 columns]

# %%
def plot_scatter1(df,columns):
  plt.figure(figsize=(14,6))
  sns.set_context('paper', font_scale=1.4)
  plt.scatter(df['number of rings'],df[columns[1]],marker="s",label=columns[1])
  plt.scatter(df['number of rings'],df[columns[2]],marker="8",label=columns[2])
  plt.scatter(df['number of rings'],df[columns[3]],marker="p",label=columns[3])
  plt.plot(df['number of rings'],df[columns[1]])
  plt.plot(df['number of rings'],df[columns[2]])
  plt.plot(df['number of rings'],df[columns[3]])
  plt.legend(bbox_to_anchor = ( 1.0, 0.8))
  plt.xticks(np.arange(1,11,step=1))
  plt.xlabel('n (number of rings)')
  plt.ylabel('HOMO-LUMO gap (eV)')

# %%
plot_scatter1(data_helicene,cols)
