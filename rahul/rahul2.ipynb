# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj18/hello_world/blob/master/rahul/rahul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
data=pd.read_excel('pankaj-2.xlsx')

# %%
data
# Out:
#     Unnamed: 0  Unnamed: 1     Thia [n]helicenes, n=1-10       Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0          NaN         NaN                           NaN  number of rings       BLYP      B3LYP    B3LYP-D       PBE0    LC-BLYP       MN15        #MO6  #CAM-B3LYP    #-wB97XD    #LC-wPBE    #LC-BLYP          HF         MP2        CCSD        mean         std
# 1          NaN         NaN                           NaN                1       4.36       5.99       5.98       8.35      10.64    7.72002        6.01        8.66         9.9       10.62       10.56       10.24        9.99       10.09     8.50786       2.065
# 2          NaN         NaN                           NaN                2       3.96       5.49       5.48       7.72       9.89     7.1165        5.55        8.07        9.29        9.97        9.92        9.57        9.37        9.46     7.91832     1.98246
# 3          NaN         NaN                           NaN                3       3.65       5.13       5.12       7.28        9.6    6.72686        5.27        7.65         8.9        9.66        9.57         9.2        9.02        9.11     7.56335     1.97849
# 4          NaN         NaN                           NaN                4       3.44       4.87       4.86       6.98       9.36    6.45204        5.06        7.35        8.59        9.44        9.35        9.04        8.84        8.96       7.328     1.98985
# 5          NaN         NaN                           NaN              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN                           NaN              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN                           NaN              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN   seleno [n]helicenes, n=1-10              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN                           NaN  number of rings       BLYP      B3LYP    B3LYP-D       PBE0    LC-BLYP       MN15        #MO6  #CAM-B3LYP    #-wB97XD    #LC-wPBE    #LC-BLYP          HF         MP2        CCSD        mean         std
# 10         NaN         NaN                           NaN                1       4.19       5.79       5.78       8.11      10.39    7.46316        5.94        8.45        9.66       10.46        10.4       10.09        9.98       10.09     8.34237     2.07657
# 11         NaN         NaN                           NaN                2        3.6       5.03       5.03       7.15       9.62    6.56006        5.32        7.59        8.72        9.69        9.66        9.37        9.29        9.35        7.57     2.04726
# 12         NaN         NaN                           NaN                3       3.34       4.74       4.73       6.79       9.41    6.23544        5.03         7.2        8.38        9.33        9.41        9.08         8.9           9     7.25539     2.03853
# 13         NaN         NaN                           NaN                4       3.13        4.5       4.49        6.5       9.18    5.97722         4.8        6.91         8.1           9        9.09        8.89        8.71        8.83     7.00766      2.0327
# 14         NaN         NaN                           NaN              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN                           NaN              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN                           NaN              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 17         NaN         NaN                           NaN              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN  Telluro [n]helicenes, n=1-10              NaN        NaN        NaN        NaN        NaN        NaN        NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN                           NaN  number of rings       BLYP      B3LYP    B3LYP-D       PBE0    LC-BLYP       MN15        #MO6  #CAM-B3LYP    #-wB97XD    #LC-wPBE    #LC-BLYP          HF         MP2        CCSD        mean         std
# 20         NaN         NaN                           NaN                1       3.73       5.14       5.12       7.22       9.66     6.5753        5.33        7.57        8.82        9.71        9.62        9.44        9.53        9.49     7.63966     2.04332
# 21         NaN         NaN                           NaN                2       2.85       4.21       4.21       6.25        8.9    5.53996        4.55        6.65        7.87        8.89        8.84        8.87         8.8        8.84       6.805      2.1133
# 22         NaN         NaN                           NaN                3       2.61       3.97       3.97       5.99       8.66    5.26677        4.35        6.39        7.62        8.65        8.58        8.74         8.6        8.66     6.57548     2.12522

# %%
columns=list(data.iloc[0,4:-2])
x=['BLYP',
 'B3LYP',
 'B3LYP-D',
 'PBE0',
 'LC-BLYP',
 'MN15',
 '$^#$MO6',
 '$^#$CAM-B3LYP',
 '$^#$-wB97XD',
 '$^#$LC-wPBE',
 '$^#$LC-BLYP',
 'HF',
 'MP2',
 'CCSD']

# %%
data_thia=data.iloc[1:5,4:-2]
data_thia.columns=columns
data_thia.reset_index(drop=True)
# Out:
#    BLYP B3LYP B3LYP-D  PBE0 LC-BLYP     MN15  #MO6 #CAM-B3LYP #-wB97XD #LC-wPBE #LC-BLYP     HF   MP2   CCSD
# 0  4.36  5.99    5.98  8.35   10.64  7.72002  6.01       8.66      9.9    10.62    10.56  10.24  9.99  10.09
# 1  3.96  5.49    5.48  7.72    9.89   7.1165  5.55       8.07     9.29     9.97     9.92   9.57  9.37   9.46
# 2  3.65  5.13    5.12  7.28     9.6  6.72686  5.27       7.65      8.9     9.66     9.57    9.2  9.02   9.11
# 3  3.44  4.87    4.86  6.98    9.36  6.45204  5.06       7.35     8.59     9.44     9.35   9.04  8.84   8.96

# %%
data_seleno=data.iloc[10:14,4:-2]
data_seleno.columns=columns
data_seleno.reset_index(drop=True)
# Out:
#    BLYP B3LYP B3LYP-D  PBE0 LC-BLYP     MN15  #MO6 #CAM-B3LYP #-wB97XD #LC-wPBE #LC-BLYP     HF   MP2   CCSD
# 0  4.19  5.79    5.78  8.11   10.39  7.46316  5.94       8.45     9.66    10.46     10.4  10.09  9.98  10.09
# 1   3.6  5.03    5.03  7.15    9.62  6.56006  5.32       7.59     8.72     9.69     9.66   9.37  9.29   9.35
# 2  3.34  4.74    4.73  6.79    9.41  6.23544  5.03        7.2     8.38     9.33     9.41   9.08   8.9      9
# 3  3.13   4.5    4.49   6.5    9.18  5.97722   4.8       6.91      8.1        9     9.09   8.89  8.71   8.83

# %%
data_telluro=data.iloc[20:23,4:-2]
data_telluro.columns=columns
data_telluro.reset_index(drop=True)
# Out:
#    BLYP B3LYP B3LYP-D  PBE0 LC-BLYP     MN15  #MO6 #CAM-B3LYP #-wB97XD #LC-wPBE #LC-BLYP    HF   MP2  CCSD
# 0  3.73  5.14    5.12  7.22    9.66   6.5753  5.33       7.57     8.82     9.71     9.62  9.44  9.53  9.49
# 1  2.85  4.21    4.21  6.25     8.9  5.53996  4.55       6.65     7.87     8.89     8.84  8.87   8.8  8.84
# 2  2.61  3.97    3.97  5.99    8.66  5.26677  4.35       6.39     7.62     8.65     8.58  8.74   8.6  8.66

# %%
def calculate_errors(df):
  error_df=pd.DataFrame()
  for col in list(df.columns):
    error_df[col+'_error_m']=df[col]-df['CCSD']
  print(error_df)
  error_df_calc=pd.DataFrame()
  error_df_calc['mue']=error_df.abs().mean(axis=0).values
  #print("mue\n")
  #print(error_df_calc['mue'])
  error_df_calc['mse']=error_df.mean(axis=0).values
  #print('\n mse \n')
  #print( error_df_calc['mse'])
  error_df_calc['max_ue']=error_df.abs().max(axis=0).values
  #print('\n max_ue \n ')
  #print(error_df_calc['max_ue'])
  error_df_calc.index=list(df.columns)
  return error_df_calc

# %% [markdown]
# # thia

# %%
x[:-1]
# Out:
# ['BLYP',
#  'B3LYP',
#  'B3LYP-D',
#  'PBE0',
#  'LC-BLYP',
#  'MN15',
#  '$^#$MO6',
#  '$^#$CAM-B3LYP',
#  '$^#$-wB97XD',
#  '$^#$LC-wPBE',
#  '$^#$LC-BLYP',
#  'HF',
#  'MP2']

# %%
error_df_thia=calculate_errors(data_thia)
print(error_df_thia)
plt.figure()
error_df_thia.iloc[0:-1].plot.bar(rot=0,figsize=(16,6))
#plt.xlabel('')
plt.ylabel('$E_{DFT}-E_{CCSD}$ eV')
# Out:
#   BLYP_error_m B3LYP_error_m B3LYP-D_error_m PBE0_error_m LC-BLYP_error_m MN15_error_m #MO6_error_m #CAM-B3LYP_error_m #-wB97XD_error_m #LC-wPBE_error_m #LC-BLYP_error_m HF_error_m MP2_error_m CCSD_error_m
# 1        -5.73          -4.1           -4.11        -1.74            0.55     -2.36998        -4.08              -1.43            -0.19             0.53             0.47       0.15        -0.1            0
# 2         -5.5         -3.97           -3.98        -1.74            0.43      -2.3435        -3.91              -1.39            -0.17             0.51             0.46       0.11       -0.09            0
# 3        -5.46         -3.98           -3.99        -1.83            0.49     -2.38314        -3.84              -1.46            -0.21             0.55             0.46       0.09       -0.09            0
# 4        -5.52         -4.09            -4.1        -1.98             0.4     -2.50796         -3.9              -1.61            -0.37             0.48             0.39       0.08       -0.12            0
#                  mue       mse   max_ue
# BLYP        5.552500 -5.552500  5.73000
# B3LYP       4.035000 -4.035000  4.10000
# B3LYP-D     4.045000 -4.045000  4.11000
# PBE0        1.822500 -1.822500  1.98000
# LC-BLYP     0.467500  0.467500  0.55000
# MN15        2.401145 -2.401145  2.50796
# #MO6        3.932500 -3.932500  4.08000
# #CAM-B3LYP  1.472500 -1.472500  1.61000
# #-wB97XD    0.235000 -0.235000  0.37000
# #LC-wPBE    0.517500  0.517500  0.55000
# #LC-BLYP    0.445000  0.445000  0.47000
# HF          0.107500  0.107500  0.15000
# MP2         0.100000 -0.100000  0.12000
# CCSD        0.000000  0.000000  0.00000
# Text(0, 0.5, '$E_{DFT}-E_{CCSD}$ eV')

# %% [markdown]
# #seleno

# %%
error_df_seleno=calculate_errors(data_seleno)
print(error_df_seleno)
plt.figure()
error_df_seleno.iloc[0:-1].plot.bar(rot=0,figsize=(16,6))
plt.ylabel('$E_{DFT}-E_{CCSD}$ eV')
# Out:
#    BLYP_error_m B3LYP_error_m B3LYP-D_error_m PBE0_error_m LC-BLYP_error_m MN15_error_m #MO6_error_m #CAM-B3LYP_error_m #-wB97XD_error_m #LC-wPBE_error_m #LC-BLYP_error_m HF_error_m MP2_error_m CCSD_error_m
# 10         -5.9          -4.3           -4.31        -1.98             0.3     -2.62684        -4.15              -1.64            -0.43             0.37             0.31          0       -0.11            0
# 11        -5.75         -4.32           -4.32         -2.2            0.27     -2.78994        -4.03              -1.76            -0.63             0.34             0.31       0.02       -0.06            0
# 12        -5.66         -4.26           -4.27        -2.21            0.41     -2.76456        -3.97               -1.8            -0.62             0.33             0.41       0.08        -0.1            0
# 13         -5.7         -4.33           -4.34        -2.33            0.35     -2.85278        -4.03              -1.92            -0.73             0.17             0.26       0.06       -0.12            0
#                 mue      mse   max_ue
# BLYP        5.75250 -5.75250  5.90000
# B3LYP       4.30250 -4.30250  4.33000
# B3LYP-D     4.31000 -4.31000  4.34000
# PBE0        2.18000 -2.18000  2.33000
# LC-BLYP     0.33250  0.33250  0.41000
# MN15        2.75853 -2.75853  2.85278
# #MO6        4.04500 -4.04500  4.15000
# #CAM-B3LYP  1.78000 -1.78000  1.92000
# #-wB97XD    0.60250 -0.60250  0.73000
# #LC-wPBE    0.30250  0.30250  0.37000
# #LC-BLYP    0.32250  0.32250  0.41000
# HF          0.04000  0.04000  0.08000
# MP2         0.09750 -0.09750  0.12000
# CCSD        0.00000  0.00000  0.00000
# Text(0, 0.5, '$E_{DFT}-E_{CCSD}$ eV')

# %% [markdown]
# # telluro

# %%
error_df_telluro=calculate_errors(data_telluro)
print(error_df_telluro)
plt.figure()
error_df_telluro.iloc[0:-1].plot.bar(rot=0,figsize=(16,6))
plt.ylabel('$E_{DFT}-E_{CCSD}$ eV')
# Out:
#    BLYP_error_m B3LYP_error_m B3LYP-D_error_m PBE0_error_m LC-BLYP_error_m MN15_error_m #MO6_error_m #CAM-B3LYP_error_m #-wB97XD_error_m #LC-wPBE_error_m #LC-BLYP_error_m HF_error_m MP2_error_m CCSD_error_m
# 20        -5.76         -4.35           -4.37        -2.27            0.17      -2.9147        -4.16              -1.92            -0.67             0.22             0.13      -0.05        0.04            0
# 21        -5.99         -4.63           -4.63        -2.59            0.06     -3.30004        -4.29              -2.19            -0.97             0.05                0       0.03       -0.04            0
# 22        -6.05         -4.69           -4.69        -2.67               0     -3.39323        -4.31              -2.27            -1.04            -0.01            -0.08       0.08       -0.06            0
#                  mue       mse   max_ue
# BLYP        5.933333 -5.933333  6.05000
# B3LYP       4.556667 -4.556667  4.69000
# B3LYP-D     4.563333 -4.563333  4.69000
# PBE0        2.510000 -2.510000  2.67000
# LC-BLYP     0.076667  0.076667  0.17000
# MN15        3.202657 -3.202657  3.39323
# #MO6        4.253333 -4.253333  4.31000
# #CAM-B3LYP  2.126667 -2.126667  2.27000
# #-wB97XD    0.893333 -0.893333  1.04000
# #LC-wPBE    0.093333  0.086667  0.22000
# #LC-BLYP    0.070000  0.016667  0.13000
# HF          0.053333  0.020000  0.08000
# MP2         0.046667 -0.020000  0.06000
# CCSD        0.000000  0.000000  0.00000
# Text(0, 0.5, '$E_{DFT}-E_{CCSD}$ eV')
